# %%
#Write a program to take two numbers as input and print their sum, difference, product, quotient, and remainder.
a=70
b=30
print("Addition of A and B is = ",a+b)
print("Subtraction of A and B is = ",a-b)
print("Multiplication of A and B is = ",a*b)
print("Division of A and B is = ",a/b)
print("Remainder of A and B is = ",a%b)
# Out:
# Addition of A and B is =  100
# Subtraction of A and B is =  40
# Multiplication of A and B is =  2100
# Division of A and B is =  2.3333333333333335
# Remainder of A and B is =  10

# %%
#Write a program to take a number as input and check whether the number is positive, negative, or zero.
num=int("Enter your Number: ")
if num>=1:
  print("The number is positive!")
elif num<1:
  print("The number is Negative!")
else:
  print("The input number is Zero")
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# Cell In[4], line 2
#       1 #Write a program to take a number as input and check whether the number is positive, negative, or zero.
# ----> 2 num = int(input("Enter your Number: "))
#       3 if num>=1:
#       4   print("The number is positive!")
#       5 elif num<1:
#
# ValueError: invalid literal for int() with base 10: ''
